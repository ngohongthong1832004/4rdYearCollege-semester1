# %%
from openai import OpenAI

# Khởi tạo client
client = OpenAI(api_key="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")

prompt = '''
**Problem 1.** Given the rating table of 4 users $U_1, U_2, U_3, U_4$ and 4 items $I_1, I_2, I_3, I_4$ as follows:
|Rating     | $I_1$    | $I_2$  | $I_3$   |  $I_4$  |
|----------|----------|--------|---------|---------|
| $U_1$    | 4     | 3     | ?    |   4 | 
| $U_2$ | 3     | 3      | 5     |   ?    |
| $U_3$  | 5     | 4      |   1  |    4 |
| $U_4$|  4   |   2    | 3 |   5|
Predict the rating $r(U_1,I_3)$ and $r(U_2, I_4)$ by using (có thể tham khảo lại slide bài giảng buổi 3-4):

a) User-based;

b) Item-based.
'''

response = client.chat.completions.create(
    model="gpt-5",
    messages=[
        {"role": "system", "content": "Bạn là trợ lý AI hữu ích."},
        {"role": "user", "content": prompt},
    ],
)

print(response.choices[0].message.content)

# %%
"""
Gửi prompt đến OpenAI Chat API và in kết quả định dạng đẹp.
Tương thích Python >= 3.7 (không cần thêm thư viện ngoài openai).
"""

import os
import textwrap
from openai import OpenAI

# ===== 1️⃣ Cấu hình API key =====
# Cách an toàn: export OPENAI_API_KEY="sk-xxxx" hoặc lưu trong .env
API_KEY = os.getenv("OPENAI_API_KEY", "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")  # fallback cho test

client = OpenAI(api_key=API_KEY)

# ===== 2️⃣ Prompt gốc =====
prompt = """
**Problem 1.** Given the rating table of 4 users U1–U4 and 4 items I1–I4:

|Rating|I1|I2|I3|I4|
|------|--|--|--|--|
|U1|4|3|?|4|
|U2|3|3|5|?|
|U3|5|4|1|4|
|U4|4|2|3|5|

Predict r(U1,I3) and r(U2,I4) using:
a) User-based CF
b) Item-based CF
"""

# ===== 3️⃣ Gửi request đến OpenAI =====
response = client.chat.completions.create(
    model="gpt-4o",  # hoặc gpt-5 nếu được cấp quyền
    messages=[
        {"role": "system", "content": "Bạn là trợ lý AI hữu ích, định dạng câu trả lời bằng Markdown rõ ràng."},
        {"role": "user", "content": prompt},
    ],
)

# ===== 4️⃣ Xử lý kết quả =====
answer = response.choices[0].message.content.strip()

# ===== 5️⃣ Hàm in đẹp có khung =====
def pretty_print(text: str, width: int = 90):
    border = "═" * (width + 4)
    print(f"\n╔{border}╗")
    for line in text.splitlines():
        for chunk in textwrap.wrap(line, width):
            print(f"║ {chunk.ljust(width)} ║")
    print(f"╚{border}╝\n")

# ===== 6️⃣ In kết quả =====
pretty_print(answer)
# Out:
# ╔══════════════════════════════════════════════════════════════════════════════════════════════╗
# ║ To predict the missing ratings using collaborative filtering, we need to determine the     ║
# ║ similarities between users or items and use these similarities to predict the unknown      ║
# ║ ratings. We'll approach this using both user-based and item-based collaborative filtering. ║
# ║ ## a) User-based Collaborative Filtering                                                   ║
# ║ ### Step 1: Compute User Similarities                                                      ║
# ║ We will use cosine similarity to compute the similarity between users.                     ║
# ║ \[ \text{Cosine Similarity} = \frac{\sum{(r_{ui} \cdot r_{vi})}}{\sqrt{\sum{r_{ui}^2}      ║
# ║ \cdot \sum{r_{vi}^2}}} \]                                                                  ║
# ║ For simplicity, assume all missing ratings are zero when computing initial similarities,   ║
# ...

# %%
import google.generativeai as genai

# 👇 Thay thế "YOUR_API_KEY" bằng API key thật của bạn
genai.configure(api_key="AIzaSyA75sKhQjVK4mpbfwxuKioE43fL0PwSyXs") 

# Phần còn lại của code giữ nguyên
model = genai.GenerativeModel("gemini-2.5-pro")
prompt = "Hãy tóm tắt ngắn gọn lịch sử phát triển của AI."

try:
    response = model.generate_content(prompt)
    print(response.text)
except Exception as e:
    print(f"Đã xảy ra lỗi: {e}")
# Out:
# Tất nhiên rồi! Dưới đây là tóm tắt ngắn gọn về lịch sử phát triển của Trí tuệ nhân tạo (AI).
#
# Lịch sử AI có thể được chia thành các giai đoạn chính, với những thăng trầm được gọi là "Mùa hè AI" (hưng phấn, nhiều tài trợ) và "Mùa đông AI" (thất vọng, cắt giảm tài trợ).
#
# **1. Giai đoạn sơ khai & Sự ra đời (1940 - 1956)**
# *   **Nền tảng lý thuyết:** Các ý tưởng về máy móc có thể "suy nghĩ" đã có từ lâu, nhưng nền tảng toán học và tính toán hiện đại được đặt ra bởi các nhà khoa học như Alan Turing.
# *   **Sự kiện khai sinh:** Thuật ngữ "Artificial Intelligence" (Trí tuệ nhân tạo) được đặt ra tại **Hội nghị Dartmouth năm 1956**, quy tụ các nhà nghiên cứu hàng đầu và chính thức khai sinh ra lĩnh vực AI.
#
# **2. Thời kỳ vàng son đầu tiên (1956 - 1974)**
# *   **Lạc quan tột độ:** Các nhà nghiên cứu tin rằng AI có thể giải quyết các vấn đề phức tạp trong vài thập kỷ.
# ...

# %%
# !pip install -q openai

from google.colab import userdata
import os
from openai import OpenAI

os.environ["OPENAI_API"] = userdata.get("OPENAI_API") or userdata.get("OPENAI_API")

client = OpenAI(api_key=os.getenv("OPENAI_API"))

topic = "Bác Hồ sinh năm bao nhiêu"

resp = client.chat.completions.create(
    model="gpt-4o-mini",  # hoặc "gpt-4o" nếu bạn có quyền
    messages=[
        {"role": "system", "content": "Bạn là trợ lý trả lời ngắn gọn và chính xác."},
        {"role": "user", "content": topic},
    ]
)

print(resp.choices[0].message.content)
