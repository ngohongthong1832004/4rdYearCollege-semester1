# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 4070 Laptop GPU

# %%
import torch
print("Có GPU không? ", torch.cuda.is_available())
print("Tên GPU: ", torch.cuda.get_device_name(0))
print("Số lượng GPU: ", torch.cuda.device_count())
print("Tổng bộ nhớ: ", torch.cuda.get_device_properties(0).total_memory / 1024**3, "GB")
print("Thông tin chi tiết: ", torch.cuda.get_device_properties(0))
# Out:
# Có GPU không?  True
# Tên GPU:  NVIDIA GeForce RTX 4070 Laptop GPU
# Số lượng GPU:  1
# Tổng bộ nhớ:  7.99560546875 GB
# Thông tin chi tiết:  _CudaDeviceProperties(name='NVIDIA GeForce RTX 4070 Laptop GPU', major=8, minor=9, total_memory=8187MB, multi_processor_count=36, uuid=60717b82-e254-3e61-423f-1c41469891f2, L2_cache_size=32MB)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
print(gpus)
# Out:
# []
